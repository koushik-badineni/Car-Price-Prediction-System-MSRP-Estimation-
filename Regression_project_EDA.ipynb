# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/car_MSRP.csv")

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Make                                          11914 non-null  object
#  1   Model                                         11914 non-null  object
#  2   Year                                          11914 non-null  int64
#  3   Engine Fuel Type                              11911 non-null  object
#  4   Engine HP                                     11845 non-null  float64
#  5   Engine Cylinders                              11884 non-null  float64
#  6   Transmission Type                             11914 non-null  object
#  7   Driven_Wheels                                 11914 non-null  object
#  8   Number of Doors                               11908 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Make                                               0
# Model                                              0
# Year                                               0
# Engine Fuel Type                                   3
# Engine HP                                         69
# Engine Cylinders                                  30
# Transmission Type                                  0
# Driven_Wheels                                      0
# Number of Doors                                    6
# Market Category                                 3742
# Vehicle Size                                       0
# Vehicle Style                                      0
# highway MPG                                        0
# city mpg                                           0
# Popularity                                         0
# MSRP (Manufacturer's suggested retail Price)       0
# dtype: int64

# %%
df.isnull().sum()/len(df)
# Out:
# Make                                            0.000000
# Model                                           0.000000
# Year                                            0.000000
# Engine Fuel Type                                0.000252
# Engine HP                                       0.005792
# Engine Cylinders                                0.002518
# Transmission Type                               0.000000
# Driven_Wheels                                   0.000000
# Number of Doors                                 0.000504
# Market Category                                 0.314084
# Vehicle Size                                    0.000000
# Vehicle Style                                   0.000000
# highway MPG                                     0.000000
# city mpg                                        0.000000
# Popularity                                      0.000000
# MSRP (Manufacturer's suggested retail Price)    0.000000
# dtype: float64

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df['Market Category']=df['Market Category'].fillna(df['Market Category'].mode()[0])

# %%
import seaborn as sns
sns.boxplot(x=df['Engine HP'])
# Out:
# <Axes: xlabel='Engine HP'>

# %% [markdown]
# as there are outliers present in the enginehp we can't impute the null values by using the median so let us use the mode

# %%
df.isnull().sum()
# Out:
# Make                                             0
# Model                                            0
# Year                                             0
# Engine Fuel Type                                 3
# Engine HP                                       69
# Engine Cylinders                                30
# Transmission Type                                0
# Driven_Wheels                                    0
# Number of Doors                                  6
# Market Category                                  0
# Vehicle Size                                     0
# Vehicle Style                                    0
# highway MPG                                      0
# city mpg                                         0
# Popularity                                       0
# MSRP (Manufacturer's suggested retail Price)     0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 715

# %%
df[df.duplicated()]
# Out:
#          Make     Model  Year             Engine Fuel Type  Engine HP  \
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# 24       Audi       100  1993             regular unleaded      172.0
# 25       Audi       100  1993             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11481  Suzuki      X-90  1998             regular unleaded       95.0
# 11603   Volvo      XC60  2017             regular unleaded      302.0
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#          Make     Model  Year             Engine Fuel Type  Engine HP  \
# 11        BMW  1 Series  2013  premium unleaded (required)      230.0
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 17       Audi       100  1992             regular unleaded      172.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11707  Suzuki       XL7  2008             regular unleaded      252.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11709  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
print("Before:", df.shape)

df = df.drop_duplicates()

print("After:", df.shape)
# Out:
# Before: (11914, 16)
# After: (11199, 16)

# %%
df.drop_duplicates()
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11199 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Make                                          11199 non-null  object
#  1   Model                                         11199 non-null  object
#  2   Year                                          11199 non-null  int64
#  3   Engine Fuel Type                              11196 non-null  object
#  4   Engine HP                                     11130 non-null  float64
#  5   Engine Cylinders                              11169 non-null  float64
#  6   Transmission Type                             11199 non-null  object
#  7   Driven_Wheels                                 11199 non-null  object
#  8   Number of Doors                               11193 non-null  float64
# ...

# %%
df['MSRP (Manufacturer\'s suggested retail Price)'].describe()
# Out:
# count    1.119900e+04
# mean     4.192593e+04
# std      6.153505e+04
# min      2.000000e+03
# 25%      2.159950e+04
# 50%      3.067500e+04
# 75%      4.303250e+04
# max      2.065902e+06
# Name: MSRP (Manufacturer's suggested retail Price), dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(df['MSRP (Manufacturer\'s suggested retail Price)'])
plt.title('Distribution of MSRP')
plt.xlabel('MSRP')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['MSRP (Manufacturer\'s suggested retail Price)'])
plt.title('Outliers in the MSRP')
plt.show()

# %% [markdown]
# Univariate Analysis

# %%
numerical_columns=df.select_dtypes(include=['int64','float64']).columns

# %%
numerical_columns
# Out:
# Index(['Year', 'Engine HP', 'Engine Cylinders', 'Number of Doors',
#        'highway MPG', 'city mpg', 'Popularity',
#        'MSRP (Manufacturer's suggested retail Price)'],
#       dtype='object')

# %%
sns.histplot(x=df['Year'])
plt.title('Distribution of Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Year'])
plt.title('Outliers in the Year')
plt.show()

# %%
sns.histplot(x=df['Engine HP'])
plt.title('Distribution of Engine HP')
plt.xlabel('Engine HP')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Engine HP'])
plt.title('Outliers in the Engine HP')
plt.show()

# %%
sns.histplot(x=df['Engine Cylinders'])
plt.title('Distribution of Engine Cylinders')
plt.xlabel('Engine Cylinders')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Engine Cylinders'])
plt.title('Outliers in the Engine Cylinders')
plt.show()

# %%
sns.histplot(x=df['Number of Doors'])
plt.title('Distribution of Number of Doors')
plt.xlabel('Number of Doors')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Number of Doors'])
plt.title('Outliers in the Number of Doors')
plt.show()

# %%
sns.histplot(x=df['highway MPG'])
plt.title('Distribution of highway MPG')
plt.xlabel('highway MPG')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['highway MPG'])
plt.title('Outliers in the highway MPG')
plt.show()

# %%
sns.histplot(x=df['city mpg'])
plt.title('Distribution of city mpg')
plt.xlabel('city mpg')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['city mpg'])
plt.title('Outliers in the city mpg')
plt.show()

# %%
sns.histplot(x=df['Popularity'])
plt.title('Distribution of Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['Popularity'])
plt.title('Outliers in the Popularity')
plt.show()

# %%
sns.histplot(x=df['MSRP (Manufacturer\'s suggested retail Price)'])
plt.title('Distribution of MSRP')
plt.xlabel('MSRP')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=df['MSRP (Manufacturer\'s suggested retail Price)'])
plt.title('Outliers in the MSRP')
plt.show()

# %% [markdown]
# categorical columns

# %%
categorical_columns=df.select_dtypes(include=['object']).columns

# %%
categorical_columns
# Out:
# Index(['Make', 'Model', 'Engine Fuel Type', 'Transmission Type',
#        'Driven_Wheels', 'Market Category', 'Vehicle Size', 'Vehicle Style'],
#       dtype='object')

# %%
top_makes = df['Make'].value_counts().head(10)

plt.figure(figsize=(10, 5))

sns.barplot(
    x=top_makes.values,
    y=top_makes.index
)

plt.title('Top 10 Car Manufacturers')
plt.xlabel('Number of Cars')
plt.ylabel('Make')

plt.show()

# %%
top_models = df['Model'].value_counts().head(10)

plt.figure(figsize=(10, 5))

sns.barplot(
    x=top_models.values,
    y=top_models.index
)

plt.title('Top 10 Most Frequent Car Models')
plt.xlabel('Number of Cars')
plt.ylabel('Model')

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.countplot(data=df, x='Engine Fuel Type')

plt.title('Distribution of Engine Fuel Type')
plt.xlabel('Engine Fuel Type')
plt.ylabel('Number of Cars')
plt.xticks(rotation=45)

plt.show()

# %%
sns.countplot(data=df, x='Vehicle Size')

plt.title('Distribution of Vehicle Size')
plt.xlabel('Vehicle Size')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df, x='Transmission Type')

plt.title('Distribution of Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(data=df, x='Driven_Wheels')

plt.title('Distribution of Driven Wheels')
plt.xlabel('Driven Wheels')
plt.ylabel('Count')
plt.show()

# %%
top_market = df['Market Category'].value_counts().head(10)

plt.figure(figsize=(10, 5))

sns.barplot(
    x=top_market.values,
    y=top_market.index
)

plt.title('Top 10 Market Categories')
plt.xlabel('Number of Cars')
plt.ylabel('Market Category')

plt.show()

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# numerical

# %%
sns.scatterplot(data=df,x='Engine HP',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('Relationship between Engine HP and MSRP')
plt.xlabel('Engine HP')
plt.ylabel('MSRP')
# Out:
# Text(0, 0.5, 'MSRP')

# %%
sns.scatterplot(data=df,x='Engine Cylinders',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('Relationship between Engine Cylinders and MSRP')
plt.xlabel('Engine Cylinders')
plt.ylabel('MSRP')
# Out:
# Text(0, 0.5, 'MSRP')

# %%
sns.scatterplot(data=df,x="highway MPG",y="MSRP (Manufacturer\'s suggested retail Price)")
plt.title('Relationship between highway MPG and MSRP')
plt.xlabel('highway MPG')
plt.ylabel('MSRP')
plt.show()

# %%
sns.scatterplot(data=df,x="city mpg",y="MSRP (Manufacturer\'s suggested retail Price)")
plt.title('Relationship between city mpg and MSRP')
plt.xlabel('city mpg')
plt.ylabel('MSRP')
plt.show()

# %%
sns.scatterplot(data=df,x="Popularity",y="MSRP (Manufacturer\'s suggested retail Price)")
plt.title('Relationship between Popularity and MSRP')
plt.xlabel('Popularity')
plt.ylabel('MSRP')
plt.show()
plt.show()

# %%
sns.scatterplot(data=df,x="Year",y="MSRP (Manufacturer\'s suggested retail Price)")
plt.title('Relationship between Year and MSRP')
plt.xlabel('Year')
plt.ylabel('MSRP')
plt.show()

# %% [markdown]
# categorical

# %%
top_makes = df['Make'].value_counts().head(10).index

df_top_makes = df[df['Make'].isin(top_makes)]

plt.figure(figsize=(12, 6))

sns.boxplot(
    data=df_top_makes,
    x='Make',
    y="MSRP (Manufacturer's suggested retail Price)"
)

plt.title('MSRP Distribution by Top 10 Car Manufacturers')
plt.xlabel('Make')
plt.ylabel('MSRP')
plt.xticks(rotation=45)

plt.show()

# %%
top_fuel=df['Engine Fuel Type'].value_counts().head(10).index
df_top_fuel=df[df['Engine Fuel Type'].isin(top_fuel)]
plt.figure(figsize=(12,6))
sns.boxplot(data=df_top_fuel,x='Engine Fuel Type',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('MSRP Distribution by Engine Fuel Type')
plt.xlabel('Engine Fuel Type')
plt.ylabel('MSRP')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df,x='Transmission Type',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('MSRP Distribution by Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('MSRP')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df,x='Driven_Wheels',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('MSRP Distribution by Driven Wheels')
plt.xlabel('Driven Wheels')
plt.ylabel('MSRP')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df,x='Vehicle Size',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('MSRP Distribution by Vehicle Size')
plt.xlabel('Vehicle Size')
plt.ylabel('MSRP')
plt.xticks(rotation=45)
plt.show()

# %%
top_styles=df['Vehicle Style'].value_counts().head(10).index
df_top_styles=df[df['Vehicle Style'].isin(top_styles)]
plt.figure(figsize=(12,6))
sns.boxplot(data=df_top_styles,x='Vehicle Style',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('MSRP Distribution by Vehicle Style')
plt.xlabel('Vehicle Style')
plt.ylabel('MSRP')
plt.xticks(rotation=45)
plt.show()

# %%
top_category=df['Market Category'].value_counts().head(10).index
df_top_category=df[df['Market Category'].isin(top_category)]
plt.figure(figsize=(12,6))
sns.boxplot(data=df_top_category,x='Market Category',y='MSRP (Manufacturer\'s suggested retail Price)')
plt.title('MSRP Distribution by Market Category')
plt.xlabel('Market Category')
plt.ylabel('MSRP')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
plt.figure(figsize=(10, 7))

numeric_df = df.select_dtypes(include='number')

correlation = numeric_df.corr()

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
correlation['MSRP (Manufacturer\'s suggested retail Price)'].sort_values(ascending=False)
# Out:
# MSRP (Manufacturer's suggested retail Price)    1.000000
# Engine HP                                       0.659174
# Engine Cylinders                                0.538712
# Year                                            0.209635
# Popularity                                     -0.048371
# Number of Doors                                -0.144925
# city mpg                                       -0.162343
# highway MPG                                    -0.166631
# Name: MSRP (Manufacturer's suggested retail Price), dtype: float64

# %%
sns.pairplot(
    df[
        [
            'Engine HP',
            'Engine Cylinders',
            'city mpg',
            'highway MPG',
            'Popularity',
            "MSRP (Manufacturer's suggested retail Price)"
        ]
    ]
)

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(x=df["MSRP (Manufacturer's suggested retail Price)"])

plt.title('Outliers in MSRP')
plt.xlabel('MSRP')

plt.show()

# %%
numerical_cols = df.select_dtypes(include='number').columns

for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Outliers in {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# **Insights**

# %% [markdown]
# Insights from car price prediction project:-
#
# 1)The top 3 car manufacturer are Chevrolet,Ford,Toyota
#
# 2)The top 3 most frequent car models are Silverado 1500,Tundra,F-150
#
# 3)In the engine fuel type
# The regular unleaded is the most common fuel type and then comes premium unleaded premium unleaded and flex-fuel is less common
# Diseal and electric is relatively rare
# Natural gas and other fuel combinations are extremely rare
#
# 4)In the vehicle size the more vehicles are of compact first and then midsize and then large
#
# 5)In the transmission type the most used one is antomatic next manual and then auto_manual
#
# 6)In the  Driven wheels
# Most of them are front wheel drive next rear wheel,then all wheel and less prefered is four wheel
#
# 7)The most market category is the crossover one and then comes Flex fuel. The maximum market category is only the crossover and less prefered are like factory tuner, luxury,high performance
#
#
# 8)As Engine Hp increases the MSRP is also increasing
# In between 400 hp and the 700 hp are below the 5,00,000
# And there are 2 outliers present that can't be considered
# Some vehicles with 1000hp are having extremely higher MSRP
#
# 9)Generally, more cylinders  higher MSRP
# Vehicles with 8, 10, 12, and 16 cylinders tend to have higher prices compared with lower-cylinder vehicles.
# This indicates a positive relationship between engine cylinders and vehicle price.
# 12-cylinder vehicles show a wide price range
# Most 12-cylinder vehicles are below 6,00,000, but a few reach around 1.4–1.5 .
# This suggests that cylinder count alone doesn't determine price.
# 16-cylinder vehicles are extremely expensive
# The few vehicles with 16 cylinders have MSRPs around 1.5–2.1.
# These are clear high-end/outlier vehicles.
# Lower-cylinder vehicles are generally cheaper
# Vehicles with 4–6 cylinders are mostly concentrated at relatively low MSRPs.
# 8-cylinder vehicles show Consideration
#
# 10)Most  vehicles have lower MPG
# Most observations are concentrated around 10–50 MPG.
# There is another smaller group around 80–110 MPG, likely representing vehicles with different powertrain technologies.
# High-priced vehicles generally have low MPG
# The vehicles with extremely high MSRPs have relatively low highway MPG.
# This suggests expensive high-performance vehicles tend to prioritize performance rather than fuel efficiency.
# There are clear MPG outliers
# A vehicle around 350 MPG stands out dramatically from the rest.
# This should be investigated as a potential data anomaly or special vehicle type rather than treated as a normal observation.
# Large variation in MSRP at low MPG
# At around 15–40 MPG, MSRP ranges from relatively inexpensive vehicles to extremely expensive vehicles.
#
# 11)In the city mpg and the msro it is Mostly an inverse relationship
# As city MPG increases, MSRP generally tends to decrease.
# However, the relationship is not strong or perfectly linear.
# Most vehicles are concentrated at lower MPG
# A large number of vehicles fall between approximately 10–40 city MPG.
# Most of these vehicles have relatively low-to-moderate MSRP.
# High-priced vehicles have low MPG
#
# This suggests that very expensive/high-performance vehicles tend to have lower fuel efficiency.
# Higher-MPG vehicles form separate clusters
# There are noticeable groups around 80–105 MPG and 120–140 MPG.
# These likely represent vehicles with alternative/hybrid powertrain characteristics.
# There are potential outliers
# Both MSRP and city MPG contain extreme observations.
#
# 12)in population and msrp
# Most vehicles have relatively low popularity
# A large concentration of vehicles is between 0–2,000 popularity.
# Their MSRP ranges from low prices to moderately high prices.
# High-priced outliers exist
# A few vehicles have extremely high MSRP values, reaching around $1.4–2.1 million.
# These occur at different popularity levels, reinforcing that popularity does not directly determine price.
# High popularity doesn't guarantee high MSRP
# Even vehicles with popularity around 4,000–5,500+ mostly have relatively low/moderate MSRP.
# This indicates that popularity alone is probably a weak predictor of vehicle price.
#
# 13)in the relationship between year and the msrp
# The models of 2000 and the below cars models the msrp is very low and the year 2001 and above the msrp is increasing and after the year 2015 the msrp is decreased once again
#
# 14)In the msrp and the cars
# Cadillac has the highest typical MSRP
# Cadillac has the highest median MSRP
#
# 15)msrp and the fuel type
# Premium Unleaded (Required) has many high-priced outliers
# It has a relatively high median MSRP and a large number of extreme values.
# Some vehicles reach $1.5–2.1 million, making this category highly right-skewed.
# Flex-Fuel categories generally have lower MSRPs
# Regular/flex-fuel vehicles tend to have lower median prices compared with premium-fuel categories.
# Their distributions are relatively concentrated.
# Diesel and Electric show moderate MSRP
# Both categories have relatively higher typical prices than regular unleaded.
# Electric vehicles show a noticeable spread, although the number of observations appears smaller.
#
# 16)In the msrp and the transmission type
# Most of the cars are of automated _manual is having the most msrp
# And the manual is having the low msrp
#
# 17)In the msrp and the Driven wheels All-wheel drive (AWD) has the highest typical MSRP
# AWD vehicles have a relatively high median price compared with the other drive types.
# They also show a very wide price range.
# Rear-wheel drive (RWD) also has a relatively high price range
# RWD has many high-priced vehicles and numerous outliers.
# Some vehicles reach around $1.4 million.
# Front-wheel drive (FWD) generally has lower MSRP
# FWD vehicles have a lower median and much smaller spread.
# There are comparatively few extreme high-price vehicles.
# Four-wheel drive (4WD) has moderate pricing
#
# 18)Msrp and the vehicle size
# Vehicle Size may contribute to MSRP prediction, but it is unlikely to be a dominant feature by itself. Features such as Make, Engine HP, cylinders, and drivetrain may provide stronger predictive information.
#
# 19)Vehicle Style appears to be a useful categorical feature for MSRP prediction, because the price distributions differ across vehicle styles.
#
# 20)Msrp by market category
# Exotic, High-Performance has by far the highest MSRP
# This category has a dramatically higher median price than the other market categories.
# It also contains the most extreme prices, exceeding $2 million.
# Luxury categories generally have higher prices
# Categories such as Luxury and Luxury, High-Performance tend to have higher MSRPs than mainstream categories.
#
# Key observations
# Engine HP has the strongest positive correlation with MSRP
# Correlation = 0.66
# As engine horsepower increases, MSRP generally increases.
# This suggests Engine HP is an important numerical feature for price prediction.
# Engine Cylinders also has a positive relationship with MSRP
# Correlation = 0.54
# Vehicles with more cylinders generally tend to have higher prices.
# Year has a weak positive correlation with MSRP
# Correlation = 0.21
# Newer vehicles tend to be somewhat more expensive, but the relationship isn't very strong.
# MPG has a weak negative correlation with MSRP
# Highway MPG: −0.17
# City MPG: −0.16
# This suggests higher-priced vehicles tend to have somewhat lower fuel efficiency, but the relationship is weak.
# Number of Doors has almost no relationship with MSRP
# Correlation = −0.14
# Therefore, the number of doors alone isn't a strong predictor of vehicle price.
# Popularity has almost no correlation with MSRP
# Correlation = −0.05

# %%
df.to_csv("cleaned_csv.CSV",index=False)
